# %% [markdown]
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](http://colab.research.google.com/github/Jonas-Metz-verovis/verovis_Coding_Challenge/blob/main/02_Data_Preprocessing_Solution.ipynb)

# %% [markdown]
# # Introduction
#
# In this Challenge you will learn how to preprocess a DataFrame and handle several Problems in the raw Data File.
#
# The Documentation of the relevant Functionalities/Packages can be found here:
#
# 1.  [Read CSV-Files with Pandas](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.read_csv.html)
# 1.  [Create Heatmaps with Seaborn](https://seaborn.pydata.org/generated/seaborn.heatmap.html)
# 1.  [Mathematical Functions (Numpy)](https://numpy.org/doc/stable/reference/routines.math.html)
#
# Info: These are Links to the official Documentation of Python and the used Packages. While comprehensive, they sometimes can be confusing. To find a Solution to a given Problem, it often works well if one just "googles the problem". Great Sources for Data Wrangling/Cleansing Functionalities are:
#
# 1.  [Pandas Data Wrangling Cheat Sheet](https://pandas.pydata.org/Pandas_Cheat_Sheet.pdf)
# 1.  [Data Cleansing Overview](https://towardsdatascience.com/data-cleaning-in-python-the-ultimate-guide-2020-c63b88bf0a0d)
# 1.  [Data Preprocessing Overview](https://towardsdatascience.com/data-preprocessing-concepts-fa946d11c825)
# 1.  [Feature Engineering Overview](https://towardsdatascience.com/feature-engineering-for-machine-learning-3a5e293a5114)
#
# Other great Sources are:
#
# 1.  [TowardsDataScience](https://towardsdatascience.com/)
# 1.  [StackOverflow](https://stackoverflow.com/)
# 1.  [Python-Kurs.eu](https://www.python-kurs.eu/python3_kurs.php)
# 1.  [Python Data Science Handbook](https://github.com/jakevdp/PythonDataScienceHandbook)
# 1.  [The Hitchhiker's Guide to Python](https://docs.python-guide.org/)
# 1.  [Overview of Data Science YouTube Channels](https://towardsdatascience.com/top-20-youtube-channels-for-data-science-in-2020-2ef4fb0d3d5)
# 1.  [Introduction to Machine Learning with Python](https://github.com/amueller/introduction_to_ml_with_python) / [Buy the Book](https://www.amazon.de/Introduction-Machine-Learning-Python-Scientists/dp/1449369413)
# 1.  [The Elements of Statistical Learning](https://web.stanford.edu/~hastie/ElemStatLearn/printings/ESLII_print12_toc.pdf)
# 1.  [Bayesian Reasoning and Machine Learning](http://web4.cs.ucl.ac.uk/staff/D.Barber/textbook/200620.pdf)
# 1.  [Deep Learning](https://www.deeplearningbook.org/)

# %% [markdown]
# # Imports

# %% [markdown]
# ### Task: Import all necessary Python Packages.

# %%
import os
import numpy as np
import pandas as pd
import seaborn as sns

# %% [markdown]
# # Data Loading

# %% [markdown]
# ### Task: Load the Data from this CSV-File into a Pandas DataFrame
#
# 1.  Titanic Train Data: https://raw.githubusercontent.com/Jonas-Metz-verovis/verovis_Coding_Challenge/main/Data/Titanic_Train_Bad_Quality.csv

# %%
df_raw_train = pd.read_csv ("https://raw.githubusercontent.com/Jonas-Metz-verovis/verovis_Coding_Challenge/main/Data/Titanic_Train_Bad_Quality.csv",
                            sep = ",",
                            header = "infer",
                            skip_blank_lines = True,
                            decimal = ".",
                            encoding = "utf-8",
                            error_bad_lines = False)
df_raw_train.head ()
# Out:
# b'Skipping line 231: expected 12 fields, saw 13\n'
#    PassengerId Survived  Pclass  \
# 0          1.0        0     3.0
# 1          2.0        1     1.0
# 2          3.0        1     3.0
# 3          4.0        1     1.0
# 4          5.0        0     3.0
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0    1.0
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0    1.0
# 2                             Heikkinen, Miss. Laina  female  26.0    0.0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0    1.0
# 4                           Allen, Mr. William Henry    male  35.0    0.0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0    0.0         A/5 21171     7.25   NaN        S
# 1    0.0          PC 17599  71.2833   C85        C
# 2    0.0  STON/O2. 3101282    7.925   NaN        S
# 3    0.0            113803     53.1  C123        S
# ...

# %% [markdown]
# # Data Inspection & Cleansing

# %% [markdown]
# ### Task: Which Columns of the DataFrame are not numeric even if they should be? Do the numeric Columns have the correct Data Type (integer/float)?

# %%
non_numerical_columns = df_raw_train.select_dtypes (exclude=[np.number]).columns.to_list ()
print (non_numerical_columns)
# Out:
# ['Survived', 'Name', 'Sex', 'Ticket', 'Fare', 'Cabin', 'Embarked']

# %%
df_raw_train.dtypes
# Out:
# PassengerId    float64
# Survived        object
# Pclass         float64
# Name            object
# Sex             object
# Age            float64
# SibSp          float64
# Parch          float64
# Ticket          object
# Fare            object
# Cabin           object
# Embarked        object
# dtype: object

# %% [markdown]
# ### Task: Inspect all Rows/Columns, what Data Quality Problems do you detect?

# %%
print ("No Solution available, yet.")

"""
INFO:
    'Fare' is interpreted as String due to the wrong Format in some Cells
    'Pclass' is interpreted as Float due to one Float Value and one missing Value (NaN)
    'PassengerId' and 'Name' contain non-unique Values
    'PassengerId' is not perfectly sorted
    'Survived' (the Target Value) contains missing Values, is interpreted as String and contains an Outlier
    'Sex' contains missing Values as well as some Outliers
    The Row of Passenger 192 is almost completely empty
    The Row of Passenger 230 has one Column too much
    'Fare' contains one extreme Value (Outlier) as well as some illogical Values (Zeros)
"""
# Out:
# No Solution available, yet.
# "\nINFO:\n    'Fare' is interpreted as String due to the wrong Format in some Cells\n    'Pclass' is interpreted as Float due to one Float Value and one missing Value (NaN)\n    'PassengerId' and 'Name' contain non-unique Values\n    'PassengerId' is not perfectly sorted\n    'Survived' (the Target Value) contains missing Values, is interpreted as String and contains an Outlier\n    'Sex' contains missing Values as well as some Outliers\n    The Row of Passenger 192 is almost completely empty\n    The Row of Passenger 230 has one Column too much\n    'Fare' contains one extreme Value (Outlier) as well as some illogical Values (Zeros)\n"

# %% [markdown]
# ### Task: Convert all Columns to their appropriate Data Type

# %%
print ("No Solution available, yet.")
# Out:
# No Solution available, yet.

# %% [markdown]
# ### Task: Create a Heatmap which visualizes the missing Values in the DataFrame

# %%
# INFO: Yellow = Missing Values
colors = ["#000000", "#FFFF00"]
sns.heatmap (df_raw_train.isnull (), cmap = sns.color_palette (colors))
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### Task: What is the Percentage of missing Values in the Columns of the DataFrame?

# %%
for column in df_raw_train.columns.to_list ():
    missing_percentage = np.mean (df_raw_train [column].isnull ())
    print ("{}:  {} % missing Values".format (column, round (missing_percentage * 100, ndigits = 2)))
# Out:
# PassengerId:  0.11 % missing Values
# Survived:  1.01 % missing Values
# Pclass:  0.11 % missing Values
# Name:  0.11 % missing Values
# Sex:  0.9 % missing Values
# Age:  19.89 % missing Values
# SibSp:  0.11 % missing Values
# Parch:  0.11 % missing Values
# Ticket:  0.11 % missing Values
# Fare:  0.11 % missing Values
# Cabin:  77.08 % missing Values
# Embarked:  0.22 % missing Values

# %% [markdown]
# ### Task: Drop all Rows which contain more than two missing Values

# %%
df_raw_train ["NumMissing"] = np.sum (df_raw_train.isnull (), axis = 1)

# %%
df_raw_train = df_raw_train.loc [df_raw_train ["NumMissing"] < 3, :]

# %% [markdown]
# ### Task: Drop the Column with the most missing Values. Discuss the Pros/Cons of dropping incomplete Samples/Columns from your Dataset.

# %%
df_raw_train = df_raw_train.drop (columns = ["Cabin"])

# %% [markdown]
# ### Task: Missing Value Imputation is a common Alternative to just dropping incomplete Samples. Research possible Methods and discuss their Pros/Cons.

# %%
print ("No Solution available, yet.")
# Out:
# No Solution available, yet.

# %% [markdown]
# ### Task: Which Values in the Columns "PassengerId" and "Name" are not unique? Discuss if this could lead to any Challenges later on.

# %%
for column in ["PassengerId", "Name"]:
    unique_values, value_counts = np.unique (df_raw_train [column], return_counts=True)
    df_uniques = pd.DataFrame (columns = ["Value", "Count"])
    df_uniques ["Value"] = unique_values
    df_uniques ["Count"] = value_counts
    df_uniques = df_uniques.loc [df_uniques ["Count"] > 1, :]

    print ("Non-unique Values in", column, ":", df_uniques ["Value"].to_list ())
# Out:
# Non-unique Values in PassengerId : [17.0]
# Non-unique Values in Name : ['Parrish, Mrs. (Lutie Davis)']

# %% [markdown]
# # Data Preprocessing

# %% [markdown]
# ### Task:

# %%
df_preprocessed_train = df_raw_train
print ("No Solution available, yet.")
# Out:
# No Solution available, yet.

# %% [markdown]
# ### Task:

# %%
print ("No Solution available, yet.")
# Out:
# No Solution available, yet.

# %% [markdown]
# # Feature Engineering

# %% [markdown]
# ### Task: Select those Features which are most likely to enable predicting the Survival of a Passenger. Discuss which Methods exist to identify relevant Features.

# %%
print ("No Solution available, yet.")
# Out:
# No Solution available, yet.

# %% [markdown]
# ### Task: Scale the numerical Variables appropriately. Discuss the available Methods as well as their Pros/Cons.

# %%
print ("No Solution available, yet.")
# Out:
# No Solution available, yet.

# %% [markdown]
# ### Task: Encode the categorical Variables appropriately. Discuss the available Methods as well as their Pros/Cons.

# %%
print ("No Solution available, yet.")
# Out:
# No Solution available, yet.

# %% [markdown]
# ### Task: Discuss if there are any special Data Preprocessing Requirements if the Data will be used to train a Linear Regression / Decision Tree / Neural Network.

# %%
print ("No Solution available, yet.")
# Out:
# No Solution available, yet.

# %% [markdown]
# ### Task: Discuss possible advanced Feature Engineering Methods which could improve the Set of Input Features. What are their respective Pros/Cons?

# %%
print ("No Solution available, yet.")
# Out:
# No Solution available, yet.

# %% [markdown]
# # Data Saving
#
# ### Info (Google Colab)
#
# If you are working in Google Colab, you can save the Results to your Google Drive by running
#
# ```
# from google.colab import drive
# drive.mount("/content/drive")
# ```
#
# You will be requested to authenticate with your Google Account.
#
# The Path to your Google Colab Notebooks Folder will be "/content/drive/My Drive/Colab Notebooks".
#
# The Commands can then use this Path:
#
# ```
# os.makedirs ("/content/drive/My Drive/Colab Notebooks/Results", exist_ok=True)
# df_preprocessed.to_csv ("/content/drive/My Drive/Colab Notebooks/Results/Titanic_Preprocessed.csv", index=False)
# ```

# %% [markdown]
# ### Task: Save the preprocessed DataFrame to a CSV-File.

# %%
os.makedirs ("Results", exist_ok=True)
df_preprocessed_train.to_csv ("Results/Titanic_Preprocessed_Train.csv", index=False)

# %% [markdown]
# ### Task: Discuss how you could persist the Data Preprocessing Steps to be able to load/replicate them during Test/Inference

# %%
print ("No Solution available, yet.")
# Out:
# No Solution available, yet.
